# %%
# importando Bibliotecas
import numpy as np
import pandas as pd

# %%
# importando CSV e transformando em Dataframe
data= pd.read_csv('UTI Total - UTI Total.csv')
data.shape
# Out:
# (73767, 2)

# %%
from pandas.core.groupby.grouper import get_grouper

#agrupando por data
data_group= data.groupby(by=['Data']).sum().sort_values(by='Data', ascending=True)
data_group.head()
# Out:
#             Quantidade de leitos COVID
# Data
# 2020-01-01                         0.0
# 2020-01-02                         0.0
# 2020-01-03                         0.0
# 2020-01-04                         0.0
# 2020-01-05                         0.0

# %%
data_pos= data_group['Quantidade de leitos COVID'] != 0
data_pos= data_group[filtro]
data_pos
# Out:
#             Quantidade de leitos COVID
# Data
# 2020-03-18                       146.0
# 2020-03-19                       146.0
# 2020-03-20                       146.0
# 2020-03-21                       146.0
# 2020-03-22                       146.0
# ...                                ...
# 2022-12-27                       125.0
# 2022-12-28                       125.0
# 2022-12-29                       125.0
# 2022-12-30                       125.0
# 2022-12-31                       125.0
#
# [1018 rows x 1 columns]

# %%
import matplotlib as mpl
from matplotlib import pyplot as plt

#mudando o tamanho da figura
plt.figure(figsize=(10,8))

#adicionando título
plt.title('Número de Leitos em Goiás entre 2019 e 2022')

plt.xlabel('Meses', fontsize=12)
plt.ylabel('Leitos', fontsize=12)
plt.xticks(rotation=45)

# Mudando a grossura dos eixos.
plt.tick_params(axis='both', labelsize=10)

#escolhendo tema
sns.set_theme(style="darkgrid")

#plotando
graph1 = sns.lineplot(data=data_pos, x='Data', y='Quantidade de leitos COVID', color='blue')
graph1
# Out:
# <AxesSubplot:title={'center':'Número de Leitos em Goiás entre 2019 e 2022'}, xlabel='Meses', ylabel='Leitos'>

# %%
# importando CSV UTI_Adulta e transformando em Dataframe
data_uti_ad= pd.read_csv('UTI_Adulta.csv')

#agrupando por data
data_uti_ad_group= data.groupby(by=['Data']).sum().sort_values(by='Data', ascending=True)

#eliminando linhas nulas
data_uti_ad_pos= data_uti_ad_group['Quantidade de leitos COVID'] != 0
data_uti_ad_pos= dados_uti_ad_group[filtro]
data_uti_ad_pos.head()
# Out:
#             Quantidade de leitos COVID
# Data
# 2020-03-18                       146.0
# 2020-03-19                       146.0
# 2020-03-20                       146.0
# 2020-03-21                       146.0
# 2020-03-22                       146.0

# %%
#definindo o tamanho da figura
plt.figure(figsize=(10,8))

#adicionando título
plt.title('Número de Leitos de UTI Adulta entre 2019 e 2022')

plt.xlabel('Meses', fontsize=12)
plt.ylabel('Leitos', fontsize=12)
plt.xticks(rotation=45)

# Mudando a grossura dos eixos.
plt.tick_params(axis='both', labelsize=10)

#escolhendo tema
sns.set_theme(style="darkgrid")

#plotando
graph2 = sns.lineplot(data=data_pos, x='Data', y='Quantidade de leitos COVID', color='green')
graph2
# Out:
# <AxesSubplot:title={'center':'Número de Leitos de UTI Adulta entre 2019 e 2022'}, xlabel='Meses', ylabel='Leitos'>

# %%
# importando CSV UTI_Neonatal e transformando em Dataframe
data_uti_neo= pd.read_csv('UTI_Neonatal.csv')

#agrupando por data
data_uti_neo= data.groupby(by=['Data']).sum().sort_values(by='Data', ascending=True)

#eliminando linhas nulas
data_uti_neo_pos= data_uti_neo['Quantidade de leitos COVID'] != 0
data_uti_neo_pos= dados_uti_neo[filtro]
data_uti_neo_pos.head()
# Out:
#             Quantidade de leitos COVID
# Data
# 2020-03-18                       146.0
# 2020-03-19                       146.0
# 2020-03-20                       146.0
# 2020-03-21                       146.0
# 2020-03-22                       146.0

# %%
# importando CSV UTI_Pediátrica e transformando em Dataframe
data_uti_ped= pd.read_csv('UTI_Ped.csv')

#agrupando por data
data_uti_ped= data.groupby(by=['Data']).sum().sort_values(by='Data', ascending=True)

#eliminando valores negativos ou nulos
data_uti_ped_pos= data_uti_ped['Quantidade de leitos COVID'] != 0
data_uti_ped_pos= dados_uti_neo[filtro]
data_uti_ped_pos.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1327/1242125651.py in <module>
#       1 # importando CSV UTI_Pediátrica e transformando em Dataframe
# ----> 2 data_uti_ped= pd.read_csv('UTI_Ped.csv')
#       3
#       4 #agrupando por data
#       5 data_uti_ped= data.groupby(by=['Data']).sum().sort_values(by='Data', ascending=True)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# importando CSV UTI_Total e transformando em Dataframe
data_uti_total= pd.read_csv('UTI_Total.csv')
data_uti_total
#agrupando por data
data_uti_total= data.groupby(by=['Data']).sum().sort_values(by='Data', ascending=True)
data_uti_total
#eliminando valores negativos ou nulos
data_uti_total_pos= data_uti_total['Quantidade de leitos COVID'] != 0
data_uti_total_pos= dados_uti_neo[filtro]
data_uti_total_pos.head()
# Out:
#             Quantidade de leitos COVID
# Data
# 2020-03-18                       146.0
# 2020-03-19                       146.0
# 2020-03-20                       146.0
# 2020-03-21                       146.0
# 2020-03-22                       146.0

# %%
graph1 = sns.lineplot(data=data_pos, x='Data', y='Quantidade de leitos COVID', color='blue')
graph2 = sns.lineplot(data=data_pos, x='Data', y='Quantidade de leitos COVID', color='green')

plt.plot(graph1, graph2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1327/86956262.py in <module>
# ----> 1 plt.plot(graph1, graph2)
#       2 plt.show()
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
# -> 1634             self.add_line(line)
# ...

# %%
#plotando
sns.lineplot(data=positivos, x='Data', y='Quantidade de leitos COVID', color='blue')
# Out:
# <AxesSubplot:xlabel='Data', ylabel='Quantidade de leitos COVID'>

# %%
sns.lineplot(data=data_pos, x='Data', y='Quantidade de leitos COVID', color='blue')
sns.lineplot(data=data_uti_total_pos, x='Data', y='Quantidade de leitos COVID', color='red')
# Out:
# <AxesSubplot:xlabel='Data', ylabel='Quantidade de leitos COVID'>

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# gerando os dados para plotagem

data=positivos, x='Data', y='Quantidade de leitos COVID', 

ax.plot(positivos.Data, positivos.Quantidade de leitos COVID, label='total', color='blue')


# definindo o nome dos eixos e Título

ax.set_xlabel('Números de Lançamentos')
ax.set_ylabel('Ano')
ax.set_title('Gráfico de Tendências')

# adicionando informações extras

plt.text(x=1970, y=400, s=r'Maioria dos filmes lançados após 2000 e as séries após 2010', fontsize=10)

# adicionando grid e legenda

plt.grid()
ax.legend()
# Out:
#   File "/tmp/ipykernel_1327/2144163218.py", line 7
#     ax.plot(positivos.Data, positivos.Quantidade de leitos COVID, label='total', color='blue')
#                                                  ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# criando o gráfico com o Matplot

fig, ax = plt.subplots()

# repare que o argumento do ax.plot gera dados aleatórios

ax.lineplot(data=positivos, x='Data', y='Quantidade de leitos COVID', color='blue')(data=positivos_uti_total, x='Data', y='Quantidade de leitos COVID', ax=graficos[0][0])
ax.lineplot(data=positivos, x='Data', y='Quantidade de leitos COVID', color='blue')(data=positivos_uti_neo, x='Data', y='Quantidade de leitos COVID', ax=graficos[0][1])
ax.lineplot(data=positivos, x='Data', y='Quantidade de leitos COVID', color='blue')(data=positivos_uti_ad, x='Data', y='Quantidade de leitos COVID', ax=graficos[1][0])

ax.set_xlabel('eixo X')
ax.set_ylabel('eixo Y')
ax.set_title('Gráfico com duas Linhas'); 

# repare que o sinal "; " ao final retira a mensagem de alerta no topo do gráfico
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1327/2297823439.py in <module>
#       7 # repare que o argumento do ax.plot gera dados aleatórios
#       8
# ----> 9 ax.lineplot(data=positivos, x='Data', y='Quantidade de leitos COVID', color='blue')
#      10 plt.show
#      11 ax.lineplot(data=positivos_uti_total, x='Data', y='Quantidade de leitos COVID', color='red')
#
# AttributeError: 'AxesSubplot' object has no attribute 'lineplot'
